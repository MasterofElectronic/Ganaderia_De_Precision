# %% [markdown]
# <a href="https://colab.research.google.com/github/andresaraque28/Ganaderia_De_Precision/blob/main/Fold1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
# !gdown --id 1haf4a97Rl9r3C9QuW_A4fszqhKW-ScBW -O fold1.zip
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1haf4a97Rl9r3C9QuW_A4fszqhKW-ScBW
# From (redirected): https://drive.google.com/uc?id=1haf4a97Rl9r3C9QuW_A4fszqhKW-ScBW&confirm=t&uuid=dca3837e-d849-4e65-88f6-d54473798bd5
# To: /content/fold1.zip
# 100% 7.69G/7.69G [01:01<00:00, 125MB/s]

# %%
# !unzip fold1.zip -d fold1
# Out:
# Archive:  fold1.zip
#    creating: fold1/Folder1/
#   inflating: fold1/Folder1/configuration.yaml
#    creating: fold1/Folder1/test/
#    creating: fold1/Folder1/test/images/
#   inflating: fold1/Folder1/test/images/050c461d-762a-4d53-8c1f-5985affefc71.JPG
#   inflating: fold1/Folder1/test/images/0be4cfb5-d6bf-4677-8014-15c0cd172533.JPG
#   inflating: fold1/Folder1/test/images/0bfaae43-5e9c-4424-a6b2-21cb6340f760.JPG
#   inflating: fold1/Folder1/test/images/0d9646c3-a017-4164-9bec-82e56316d608.JPG
#   inflating: fold1/Folder1/test/images/0e0d79d9-f891-46a4-99af-86008ffc1db4.JPG
#   inflating: fold1/Folder1/test/images/0f7884e5-0bc7-4698-bb09-a0406daa33b7.JPG
#   inflating: fold1/Folder1/test/images/129eac87-26c5-4f37-a81b-a19e0555173b.JPG
#   inflating: fold1/Folder1/test/images/12e4fb78-e573-42e3-8530-2c7af57710d9.JPG
#   inflating: fold1/Folder1/test/images/146c8f91-b7d4-4db7-b223-546079cc09b3.JPG
#   inflating: fold1/Folder1/test/images/189c1172-d70d-4eb9-b9f5-033095b088ca.JPG
# ...

# %%
# !python3.10 -m pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 723.1/723.1 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 60.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 76.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
# ...

# %%
#se importa yolo
from ultralytics import YOLO

# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 524, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are {'val', 'track', 'predict', 'benchmark', 'train', 'export'}.
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of {'pose', 'detect', 'classify', 'segment', 'obb'}
#                 MODE (required) is one of {'val', 'track', 'predict', 'benchmark', 'train', 'export'}
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data='/content/fold1/Folder1/configuration.yaml' epochs=40 imgsz=640 patience=5
# Out:
# ...
# 100% 49.7M/49.7M [00:00<00:00, 276MB/s]
# Ultralytics YOLOv8.1.37 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display, HTML
titulo = 'resultados'

# Mostrar la imagen y el título
display(HTML(f'<h2>{titulo}</h2>'))
Image(filename= f'/content/runs/detect/train/results.png', width= 600 )
# Out:
# <h2>resultados</h2>

# %%
titulo = 'Matriz de confusion'

# Mostrar la imagen y el título
display(HTML(f'<h2>{titulo}</h2>'))
Image(filename= f'/content/runs/detect/train/confusion_matrix.png', width= 600 )
# Out:
# <h2>Matriz de confusion</h2>
