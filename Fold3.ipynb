# %% [markdown]
# <a href="https://colab.research.google.com/github/andresaraque28/Ganaderia_De_Precision/blob/main/fold3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown --id 1VAnVf1uOz7lEp0Ur0Ndp5dkop2pdURIN -O fold3.zip
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/cli.py:138: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1VAnVf1uOz7lEp0Ur0Ndp5dkop2pdURIN
# From (redirected): https://drive.google.com/uc?id=1VAnVf1uOz7lEp0Ur0Ndp5dkop2pdURIN&confirm=t&uuid=4e242f28-1909-4cc6-9ad4-9b40d863b7ef
# To: /content/fold3.zip
# 100% 7.69G/7.69G [01:02<00:00, 124MB/s]

# %%
# !unzip fold3.zip -d fold3
# Out:
# Archive:  fold3.zip
#    creating: fold3/Folder3/
#   inflating: fold3/Folder3/configuration.yaml
#    creating: fold3/Folder3/test/
#    creating: fold3/Folder3/test/images/
#   inflating: fold3/Folder3/test/images/050c461d-762a-4d53-8c1f-5985affefc71.JPG
#   inflating: fold3/Folder3/test/images/0be4cfb5-d6bf-4677-8014-15c0cd172533.JPG
#   inflating: fold3/Folder3/test/images/0bfaae43-5e9c-4424-a6b2-21cb6340f760.JPG
#   inflating: fold3/Folder3/test/images/0d9646c3-a017-4164-9bec-82e56316d608.JPG
#   inflating: fold3/Folder3/test/images/0e0d79d9-f891-46a4-99af-86008ffc1db4.JPG
#   inflating: fold3/Folder3/test/images/0f7884e5-0bc7-4698-bb09-a0406daa33b7.JPG
#   inflating: fold3/Folder3/test/images/129eac87-26c5-4f37-a81b-a19e0555173b.JPG
#   inflating: fold3/Folder3/test/images/12e4fb78-e573-42e3-8530-2c7af57710d9.JPG
#   inflating: fold3/Folder3/test/images/146c8f91-b7d4-4db7-b223-546079cc09b3.JPG
#   inflating: fold3/Folder3/test/images/189c1172-d70d-4eb9-b9f5-033095b088ca.JPG
# ...

# %%
# !python3.10 -m pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 744.5/744.5 kB 11.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 12.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 46.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 53.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 10.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.0 MB/s eta 0:00:00
# ...

# %%
#se importa yolo
from ultralytics import YOLO

# !yolo mode=checks
# Out:
# requirements: Ultralytics requirement ['git+https://github.com/ultralytics/CLIP.git'] not found, attempting AutoUpdate...
# ...
#   Cloning https://github.com/ultralytics/CLIP.git to /tmp/pip-req-build-npa0shld
#   Resolved https://github.com/ultralytics/CLIP.git to commit e17416a36b45d040758327936a1ea150c13fe3d1
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.4/54.4 kB 4.0 MB/s eta 0:00:00
# ...
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369504 sha256=6d693680028a9bdb7f9cd6b6412e1016a0591b0cc0e38fd01dbbffe690414f5b
#   Stored in directory: /tmp/pip-ephem-wheel-cache-eqp7glip/wheels/2e/25/92/e26f2a227599930e19a8188891e9600b6dd36721a0f8d6ef40
# Successfully built clip
# ...
#
# requirements: AutoUpdate success ✅ 9.7s, installed 1 package: ['git+https://github.com/ultralytics/CLIP.git']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# ...

# %%
# !yolo task=detect mode=train model=yolov8m.pt data='/content/fold3/Folder3/configuration.yaml' epochs=40 imgsz=640 patience=5
# Out:
# Ultralytics YOLOv8.1.39 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from IPython.display import Image, display, HTML
titulo = 'resultados'

# Mostrar la imagen y el título
display(HTML(f'<h2>{titulo}</h2>'))
Image(filename= f'/content/runs/detect/train2/results(3).png', width= 600 )
# Out:
# <h2>resultados</h2>

# %%
titulo = 'Matriz de confusion'

# Mostrar la imagen y el título
display(HTML(f'<h2>{titulo}</h2>'))
Image(filename= f'/content/runs/detect/train2/confusion_matrix(3).png', width= 600 )
# Out:
# <h2>Matriz de confusion</h2>
